# %%
import pandas as pd
vendas_df = pd.read_csv("dados.csv", sep=";", encoding="utf-8")
vendas_df["CIDADE"].value_counts()
# Out:
# CIDADE
# SAMAMBAIA                             836
# CEILANDIA                             331
# JARDIM BOTÂNICO                       291
# RIACHO FUNDO II                       262
# GUARA                                 252
# SAO SEBASTIAO                         149
# BRASILIA                              141
# RECANTO DAS EMAS                      135
# TAGUATINGA                             66
# PARANOA                                60
# GAMA                                   53
# ARNIQUEIRA                             47
# SANTA MARIA                            41
# PLANALTINA                             37
# SOBRADINHO                             32
# ITAPOÃ                                 32
# LAGO NORTE                             24
# VICENTE PIRES                          18
# RIACHO FUNDO                           12
# NUCLEO BANDEIRANTE                     10
# SETOR DE INDUSTRIA E ABASTECIMENTO      5
# BRAZLANDIA                              4
# ...
